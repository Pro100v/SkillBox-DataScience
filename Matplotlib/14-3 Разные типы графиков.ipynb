# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
from matplotlib import colors as clr
import matplotlib.cbook as cbook
import math

# %%
df = pd.read_csv('./data/AB_NYC_2019.csv')
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df[df['reviews_per_month'].isna()]['number_of_reviews'].sum()
# Out:
# 0

# %%
print('neighbourhood_group: ', df['neighbourhood_group'].unique())
print('neighbourhood: ', df['neighbourhood'].unique())
print('room_type: ', df['room_type'].unique())
# Out:
# neighbourhood_group:  ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# neighbourhood:  ['Kensington' 'Midtown' 'Harlem' 'Clinton Hill' 'East Harlem'
#  'Murray Hill' 'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side'
#  'Chinatown' 'South Slope' 'West Village' 'Williamsburg' 'Fort Greene'
#  'Chelsea' 'Crown Heights' 'Park Slope' 'Windsor Terrace' 'Inwood'
#  'East Village' 'Greenpoint' 'Bushwick' 'Flatbush' 'Lower East Side'
#  'Prospect-Lefferts Gardens' 'Long Island City' 'Kips Bay' 'SoHo'
#  'Upper East Side' 'Prospect Heights' 'Washington Heights' 'Woodside'
#  'Brooklyn Heights' 'Carroll Gardens' 'Gowanus' 'Flatlands' 'Cobble Hill'
#  'Flushing' 'Boerum Hill' 'Sunnyside' 'DUMBO' 'St. George' 'Highbridge'
#  'Financial District' 'Ridgewood' 'Morningside Heights' 'Jamaica'
#  'Middle Village' 'NoHo' 'Ditmars Steinway' 'Flatiron District'
#  'Roosevelt Island' 'Greenwich Village' 'Little Italy' 'East Flatbush'
# ...

# %%
df.groupby(['room_type']).size()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# dtype: int64

# %%
df.pivot_table(index=['room_type'], columns=['neighbourhood_group'], aggfunc=np.size, values='id')
# Out:
# neighbourhood_group  Bronx  Brooklyn  Manhattan  Queens  Staten Island
# room_type
# Entire home/apt        379      9559      13199    2096            176
# Private room           652     10132       7982    3372            188
# Shared room             60       413        480     198              9

# %%
colors = clr.get_named_colors_mapping()
color_map = {
    'Brooklyn': colors['xkcd:cloudy blue'],
    'Manhattan': colors['xkcd:azul'],
    'Queens': colors['xkcd:electric lime'],
    'Staten Island': colors['xkcd:fresh green'],
    'Bronx': colors['xkcd:warm purple'],
}

# %%
plt.figure(figsize=(10, 10))
# with cbook.get_sample_data('ada.png') as im_file:
#     im = plt.imread(im_file)
im = plt.imread('./data/datasets_268833_611395_New_York_City_.png', 0)
# extent = (
#     math.floor(min(df['longitude'])) + 0.65, 
#     math.ceil(max(df['longitude'])) - 0.65, 
#     math.floor(min(df['latitude'])) + 0.1, 
#     math.ceil(max(df['latitude'])) - 0.1
# )

extent = (
    min(df['longitude']) + 0.013, 
    max(df['longitude']), 
    min(df['latitude']) - 0.01,
    max(df['latitude'])
)

plt.imshow(im, origin='upper', extent=extent)

for name, group in df.groupby(['neighbourhood_group']):
    plt.scatter(group['longitude'], group['latitude'], s=0.1, c=color_map[name], label=name, alpha=0.7)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.legend(markerscale=10)
plt.title('Accomodation location by neighbourhood_group')
plt.show()

# %% [markdown]
# ## Bar

# %%
plt.figure(figsize=(10, 5))
x = np.asarray([0, 1, 2])
width = 0.15
i = -2


# plt.imread('./data/New_York_City_.png')
for name, group in df.groupby(['neighbourhood_group']):
    plt.bar(x - i*width, group.groupby('room_type').size().values, width, label=name)
    i += 1
        
# plt.xlabel('longitude')
# plt.ylabel('latitude')
plt.legend(markerscale=10)
plt.title('Accomodation location by neighbourhood_group')
plt.xticks(x, list(df.groupby('room_type').groups.keys()))
# Out:
# ([<matplotlib.axis.XTick at 0x2b89e786f48>,
# ...
#  [Text(0, 0, 'Entire home/apt'),
#   Text(0, 0, 'Private room'),
#   Text(0, 0, 'Shared room')])

# %% [markdown]
# ## Hist

# %%
plt.figure(figsize=(10, 5))
filtered_df = df[df['price'] < 1000]
for name, group in filtered_df.groupby(['neighbourhood_group']):
    plt.hist(group['price'], label=name, bins=50, alpha=0.3)
plt.xlabel('Price, $')
plt.ylabel('Accomodation quantity')
plt.title('Price distribution by neighbourhood_group')
plt.legend()

# %% [markdown]
# ## Pie

# %%
neighbourhood_group_size = df.groupby(['neighbourhood_group']).size()
neighbourhood_group_size
# Out:
# neighbourhood_group
# Bronx             1091
# Brooklyn         20104
# Manhattan        21661
# Queens            5666
# Staten Island      373
# dtype: int64

# %%
plt.figure(figsize=(8, 8))
plt.pie(neighbourhood_group_size.values, labels=neighbourhood_group_size.index, autopct='%1.2f%%')
plt.legend()

# %% [markdown]
# ## Boxplot

# %%
filtered_df = df[df['price'] < 1000]

# %%
plt.figure(figsize=(10,8))
index = 1
for name, group in filtered_df.groupby(['neighbourhood_group']):
    plt.boxplot(group['price'], positions=[index], labels=[name], autorange=False, showfliers=False)
    index += 1
plt.xlabel('neighbourhood_group')
plt.ylabel('Price, $')
plt.title('Price distribution by neighbourhood_group')
# Out:
# Text(0.5, 1.0, 'Price distribution by neighbourhood_group')
